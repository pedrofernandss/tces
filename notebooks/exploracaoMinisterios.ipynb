# %%
import pandas as pd

# %%
ministeriosDatabaseURL = '../database/raw/min2.xlsx'
ministeriosDataframe = pd.read_excel(ministeriosDatabaseURL)
ministeriosDataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 31 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   MINISTERIO                            408 non-null    object
#  1   Ano                                   408 non-null    int64
#  2   PartidoCod                            404 non-null    object
#  3   TotalIniciativas                      404 non-null    float64
#  4   Mandato                               408 non-null    object
#  5   Governo                               408 non-null    object
#  6   TipoMinistro                          404 non-null    object
#  7   Popularity                            408 non-null    float64
#  8   TimeElection                          408 non-null    int64
#  9   DepNDAS5e6                            405 non-null    float64
#  10  LogTotal                              402 non-null    float64
# ...

# %%
colunasDeInteresse = ministeriosDataframe[['MINISTERIO', 'Ano', 'PartidoCod', 'TotalIniciativas', 'Mandato', 'Governo', 'TipoMinistro', 'Popularity']]
colunasDeInteresse
# Out:
#       MINISTERIO   Ano PartidoCod  TotalIniciativas Mandato Governo  \
# 0    AGRICULTURA  1999        PPB               3.0    FHC2     FHC
# 1    AGRICULTURA  2000        PPB               6.0    FHC2     FHC
# 2    AGRICULTURA  2001        PPB               2.0    FHC2     FHC
# 3    AGRICULTURA  2002        PPB               8.0    FHC2     FHC
# 4    AGRICULTURA  2003        SFP               2.0   LULA1    Lula
# ..           ...   ...        ...               ...     ...     ...
# 403      TURISMO  2012       PMDB               0.0  DILMA1   Dilma
# 404      TURISMO  2013       PMDB               0.0  DILMA1   Dilma
# 405      TURISMO  2014        SFP               0.0  DILMA1   Dilma
# 406      TURISMO  2015       PMDB               0.0  DILMA2   Dilma
# 407      TURISMO  2016       PMDB               0.0  TEMER1   Temer
#
#               TipoMinistro  Popularity
# 0     Parceiro da Coalizao       29.85
# 1     Parceiro da Coalizao       31.75
# ...

# %%
qtndValoresUnicos = ministeriosDataframe['MINISTERIO'].nunique()
print(f"Há {qtndValoresUnicos} ministérios diferentes na coluna de ministérios")

print("-----------------------------------------------------------------------------")

valoresUnicos = ministeriosDataframe['MINISTERIO'].unique()

for i in valoresUnicos: 
    print(i)
# Out:
# Há 24 ministérios diferentes na coluna de ministérios
# -----------------------------------------------------------------------------
# AGRICULTURA
# CIDADES
# CIENCIA
# COMUNICACOES
# CULTURA
# DEFESA
# DESENV. AGRARIO
# DESENV. SOCIAL
# EDUCACAO
# ESPORTE
# FAZENDA
# INDUSTRIA
# INTEGRACAO
# JUSTICA
# MEIO AMBIENTE
# MINAS E ENERGIA
# PESCA
# PLANEJAMENTO
# PREVIDENCIA
# REL. EXTERIORES
# SAUDE
# TRABALHO
# TRANSPORTES
# TURISMO
